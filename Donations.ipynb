# %% [markdown]
# # Political Donations
#
# This is my second project on python

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
donations = pd.read_csv("political_donations2.csv",low_memory=False)

# %%
donations.head()
# Out:
#              cmte_id       cand_id                       cand_nm  \
# C00458844  P60006723  Rubio, Marco              GREEN, PERRY MR.
# C00458844  P60006723  Rubio, Marco       ALASKA REPUBLICAN PARTY
# C00458844  P60006723  Rubio, Marco                 JOHNSON, MARK
# C00458844  P60006723  Rubio, Marco                    ENTERPRISE
# C00458844  P60006723  Rubio, Marco  U.S. SPACE AND ROCKET CENTER
#
#            recipient_nm   disb_amt     disb_dt recipient_city recipient_st  \
# C00458844        500.00  15-SEP-15   ANCHORAGE             AK    995084442
# C00458844       2500.00  16-NOV-15   ANCHORAGE             AK        99503
# C00458844       1000.00  30-SEP-15   ANCHORAGE             AK    995163436
# C00458844        336.09  18-DEC-15  BIRMINGHAM             AL    352124572
# C00458844       2000.00  07-APR-16  HUNTSVILLE             AL        35805
#
#                   recipient_zip disb_desc  \
# C00458844  IN-KIND CONTRIBUTION       NaN
# ...

# %%
donations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 292554 entries, C00458844 to C00623884
# Data columns (total 16 columns):
# cmte_id           292554 non-null object
# cand_id           292554 non-null object
# cand_nm           292554 non-null object
# recipient_nm      292554 non-null float64
# disb_amt          292554 non-null object
# disb_dt           292507 non-null object
# recipient_city    292554 non-null object
# recipient_st      292386 non-null object
# recipient_zip     292398 non-null object
# disb_desc         173203 non-null object
# memo_cd           24607 non-null object
# memo_text         292554 non-null object
# form_tp           292554 non-null int64
# file_num          292554 non-null object
# tran_id           247888 non-null object
# election_tp       0 non-null float64
# dtypes: float64(2), int64(1), object(13)
# memory usage: 37.9+ MB

# %%
donations['recipient_nm'].mean()
# Out:
# 5126.5289910922429

# %% [markdown]
# There are 292,559 entries for most of the parameters but for some. Be aware of that

# %% [markdown]
# ## Total donations by candidate
#
# We sum all donations by each candidate

# %%
df=donations.groupby("cand_nm").sum().sort_values(by=["recipient_nm"], ascending=False)

# %%
del df['election_tp']

# %%
df
# Out:
#                                            recipient_nm      form_tp
# cand_nm
# GMMB                                       3.084634e+08    184273720
# GILES-PARSCALE                             8.783838e+07    109171062
# OLD TOWNE MEDIA INC                        8.304847e+07     71253279
# AMERICAN MEDIA & ADVOCACY GROUP            7.417638e+07      9079566
# BULLY PULPIT INTERACTIVE LLC               3.330646e+07    100475350
# REVOLUTION MESSAGING, LLC                  2.869700e+07     70083586
# ADP                                        2.790281e+07    208480113
# RICK REED MEDIA, INC.                      2.435987e+07     23458950
# AMERICAN EXPRESS                           2.084720e+07  19691612879
# WESTROGERS LLC                             2.009115e+07     40030741
# SMART MEDIA GROUP LLC                      1.841945e+07     23187429
# MARKHAM PRODUCTIONS                        1.602585e+07    650164724
# ...

# %%
df["recipient_nm"].plot(kind="bar")

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-72b44c061663> in <module>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable
